# %%
import pandas as pd
import numpy as np

# %%
df1 = pd.read_excel('Filter_data_mum_mahr_delhi_gujr.xlsx',index_col=0)

# %%
df1.head()
# Out:
#          state                                             Name
# 0      GUJARAT            ECOVISION ENVIRONMENTAL RESOURCES LLP  \
# 1      GUJARAT                          Alliance Fibres Limited
# 2  MAHARASHTRA                    THE SHAKTI PLASTIC INDUSTRIES
# 3        DELHI  Timarpur-Okhla Waste Management Company Limited
# 4  MAHARASHTRA                            MITTAL POLYGRAINS LLP
#
#                                              Address
# 0  Survey No. 11, 12, 13, Opp. Torrent Power, Sub...  \
# 1  Block 203 & 208, MOTA BORASARA, KIM, TAL - MAN...
# 2  GUT NO 159 & 158, VILLAGE NANDGAON TURFE MANOR...
# 3  Old NDMC Compost Plant , Behind CRRI Mathura R...
# 4  Gut No. 41, Plot No. 27 & 28, Karodi, Aurangab...
#
#                             Email                    Class
# 0           info@eco-vision.co.in  Plastic waste Recycling  \
# 1         info@alliancefibres.com  Plastic waste Recycling
# 2    yogesh@shaktiplasticinds.com  Plastic waste Recycling
# ...

# %%
# import pandas as pd
# import requests
# from bs4 import BeautifulSoup

# # assuming your series is named 'companies'
# for company in df['Name']:
#     # search for the company website using Bing
#     search_url = f'https://www.google.com/search?q={company}+website'
#     search_page = requests.get(search_url)
#     soup = BeautifulSoup(search_page.text, 'html.parser')
#     website_url = soup.find('cite').text

#     # visit the company website and find the contact information
#     company_page = requests.get(website_url)
#     soup = BeautifulSoup(company_page.text, 'html.parser')
#     contact_info = soup.find('a', {'class': 'contact'})
#     print(f'{company}: {contact_info}')

# %%
# import pandas as pd
# import requests
# from bs4 import BeautifulSoup

# # Load the company names from the dataframe
# #df = pd.DataFrame({'Company': ['Company A', 'Company B', 'Company C']})

# # Create a list to store the contact numbers
# contact_numbers = []

# # Iterate over each company name
# for company_name in df['Name']:
#     # Construct the Google search query
#     query = f'{company_name} contact number'

#     # Send a GET request to Google search
#     response = requests.get(f"https://www.google.com/search?q={query}")

#     # Parse the HTML content using BeautifulSoup
#     soup = BeautifulSoup(response.text, 'html.parser')

#     # Find the search results container
#     search_results = soup.find_all('div', class_='g')

#     # Extract the contact number from the first search result
#     contact_number = None
#     for result in search_results:
#         # Find the URL of the search result
#         url = result.find('a')['href']
#         if 'http' in url:
#             # Send a GET request to the search result URL
#             result_page = requests.get(url)
#             result_soup = BeautifulSoup(result_page.text, 'html.parser')

#             # Extract the contact number if available
#             contact_element = result_soup.find(text='Contact')
#             if contact_element:
#                 contact_number = contact_element.find_next('p').text
#                 break
    
#     # Append the contact number to the list
#     contact_numbers.append(contact_number)

# # Add the contact numbers to the dataframe
# #df['Contact Number'] = contact_numbers

# # Print the updated dataframe
# print(contact_numbers)

# %%
df1.shape
# Out:
# (1189, 7)

# %%
# import pandas as pd
# import requests
# from bs4 import BeautifulSoup

# # Load the company names from the dataframe
# #df = pd.DataFrame({'Company': ['Company A', 'Company B', 'Company C']})

# # Create a list to store the contact numbers
# contact_numbers = []

# # Iterate over each company name
# for company_name in df['Name']:
#     # Construct the Google search query
#     query = f'{company_name} contact number'

#     try:
#         # Send a GET request to Google search
#         response = requests.get(f"https://www.google.com/search?q={query}")

#         # Parse the HTML content using BeautifulSoup
#         soup = BeautifulSoup(response.text, 'html.parser')

#         # Find the search results container
#         search_results = soup.find_all('div', class_='g')

#         # Extract the contact number from the first search result
#         contact_number = None
#         for result in search_results:
#             # Find the URL of the search result
#             url = result.find('a')['href']
#             if 'http' in url:
#                 # Send a GET request to the search result URL
#                 result_page = requests.get(url)
#                 result_soup = BeautifulSoup(result_page.text, 'html.parser')

#                 # Extract the contact number if available
#                 contact_element = result_soup.find(text='Contact')
#                 if contact_element:
#                     contact_number = contact_element.find_next('p').text
#                     break

#         # Append the contact number to the list
#         contact_numbers.append(contact_number)

#     except requests.exceptions.RequestException as e:
#         # Handle the exception
#         print(f"An error occurred while processing {company_name}: {e}")
#         contact_numbers.append(None)

# # Add the contact numbers to the dataframe
# #df['Contact Number'] = contact_numbers

# # Print the updated dataframe
# #print(contact_numbers)

# %%
import pandas as pd
import requests
from bs4 import BeautifulSoup

# Example DataFrame with data

# Extract contact details from Google search
def extract_contact_details(name):
    search_query = f"{name} contact details"
    url = f"https://www.google.com/search?q={search_query}"
    headers = {
        'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/91.0.4472.124 Safari/537.36'
    }
    response = requests.get(url, headers=headers)
    soup = BeautifulSoup(response.text, 'html.parser')
    
    # Extract the contact details from the search results
    contact_details = soup.find('div', class_='wpb_wrapper')
    
    return contact_details.text if contact_details else ''

# Apply the function to each row in the DataFrame
df1['Contact Details'] = df['Name'].apply(extract_contact_details)

# Display the updated DataFrame
#print(df)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[20], line 23
#      20     return contact_details.text if contact_details else ''
#      22 # Apply the function to each row in the DataFrame
# ---> 23 df1['Contact Details'] = df['Name'].apply(extract_contact_details)
#
# NameError: name 'df' is not defined

# %%
df1
# Out:
#             state                                             Name
# 0         GUJARAT            ECOVISION ENVIRONMENTAL RESOURCES LLP  \
# 1         GUJARAT                          Alliance Fibres Limited
# 2     MAHARASHTRA                    THE SHAKTI PLASTIC INDUSTRIES
# 3           DELHI  Timarpur-Okhla Waste Management Company Limited
# 4     MAHARASHTRA                            MITTAL POLYGRAINS LLP
# ...           ...                                              ...
# 1185      GUJARAT              SANDBERRY FIBRETECH PRIVATE LIMITED
# 1186  MAHARASHTRA                                      B K DISPOSE
# 1187        DELHI                          AMIT PLASTIC INDUSTRIES
# 1188        DELHI                            ATULYA PORIMA LIMITED
# 1189        DELHI                                  SONI INDUSTRIES
#
#                                                 Address
# 0     Survey No. 11, 12, 13, Opp. Torrent Power, Sub...  \
# ...

# %%
df1['Contact Details'].sample(20)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\anaconda3\envs\web_scapping\lib\site-packages\pandas\core\indexes\base.py:3652, in Index.get_loc(self, key)
#    3651 try:
# -> 3652     return self._engine.get_loc(casted_key)
#    3653 except KeyError as err:
#
# File ~\anaconda3\envs\web_scapping\lib\site-packages\pandas\_libs\index.pyx:147, in pandas._libs.index.IndexEngine.get_loc()
#
# File ~\anaconda3\envs\web_scapping\lib\site-packages\pandas\_libs\index.pyx:176, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:7080, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Contact Details'
#
# The above exception was the direct cause of the following exception:
#
# ...

# %%
import pandas as pd
import requests
from bs4 import BeautifulSoup
import re

# Example DataFrame with data
# df = pd.DataFrame({
#     'State': ['GUJARAT', 'GUJARAT', 'MAHARASHTRA', 'DELHI', 'MAHARASHTRA'],
#     'Name': ['ECOVISION ENVIRONMENTAL RESOURCES LLP', 'Alliance Fibres Limited', 'THE SHAKTI PLASTIC INDUSTRIES', 'Timarpur-Okhla Waste Management Company Limited', 'MITTAL POLYGRAINS LLP'],
#     'Address': ['Survey No. 11, 12, 13, Opp. Torrent Power, Sub...', 'Block 203 & 208, MOTA BORASARA, KIM, TAL - MAN...', 'GUT NO 159 & 158, VILLAGE NANDGAON TURFE MANOR...', 'Old NDMC Compost Plant , Behind CRRI Mathura R...', 'Gut No. 41, Plot No. 27 & 28, Karodi, Aurangab...'],
#     'Email': ['info@eco-vision.co.in', 'info@alliancefibres.com', 'yogesh@shaktiplasticinds.com', 'sandip.dutt@jindalecopolis.com', 'accounts@mittalpolygrains.in'],
#     'Class': ['Plastic waste Recycling', 'Plastic waste Recycling', 'Plastic waste Recycling', 'Waste to energy Plants', 'Plastic waste Recycling'],
#     'Category': ['CAT I,CAT II', 'CAT I', 'CAT I,CAT II,CAT III', 'CAT I,CAT II,CAT III', 'CAT I,CAT II,CAT III'],
#     'Website': [''] * 5  # Add an empty column for website URLs
# })

# Set up your Google Custom Search API credentials
API_KEY = ' AIzaSyDwJJ6RIAoKdgDGfZbrLJKq0I8y4t5gz5M'
SEARCH_ENGINE_ID = '979e664b86ac2498d'

# Function to search for website URL using Google Custom Search API
def search_website_url(query):
    url = f'https://www.googleapis.com/customsearch/v1'
    params = {
        'key': API_KEY,
        'cx': SEARCH_ENGINE_ID,
        'q': query
    }
    response = requests.get(url, params=params)
    results = response.json()
    
    # Extract the first search result URL
    if 'items' in results:
        return results['items'][0]['link']
    
    return ''

# Function to scrape contact details from a website
def scrape_contact_details(url):
    response = requests.get(url)
    soup = BeautifulSoup(response.content, 'html.parser')
    
    # Extract contact details using appropriate selectors or regular expressions
    contact_info = soup.select('.contact-info')  # Example selector
    contact_numbers = re.findall(r'\b\d{3}[-.]?\d{3}[-.]?\d{4}\b', str(contact_info))
    
    return contact_numbers

# Iterate over the DataFrame rows
for index, row in df1.iterrows():
    name = row['Name']
    
    # Search

# %%
df1
# Out:
#             state                                             Name
# 0         GUJARAT            ECOVISION ENVIRONMENTAL RESOURCES LLP  \
# 1         GUJARAT                          Alliance Fibres Limited
# 2     MAHARASHTRA                    THE SHAKTI PLASTIC INDUSTRIES
# 3           DELHI  Timarpur-Okhla Waste Management Company Limited
# 4     MAHARASHTRA                            MITTAL POLYGRAINS LLP
# ...           ...                                              ...
# 1185      GUJARAT              SANDBERRY FIBRETECH PRIVATE LIMITED
# 1186  MAHARASHTRA                                      B K DISPOSE
# 1187        DELHI                          AMIT PLASTIC INDUSTRIES
# 1188        DELHI                            ATULYA PORIMA LIMITED
# 1189        DELHI                                  SONI INDUSTRIES
#
#                                                 Address
# 0     Survey No. 11, 12, 13, Opp. Torrent Power, Sub...  \
# ...

# %%
from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.support.wait import WebDriverWait
from selenium.webdriver.chrome.options import Options
from selenium.webdriver.support import expected_conditions as EC
from webdriver_manager.chrome import ChromeDriverManager
from selenium.webdriver.common.keys import Keys
import time

# %%
from selenium import webdriver

# Example DataFrame with data
# df = pd.DataFrame({
#     'State': ['GUJARAT', 'GUJARAT', 'MAHARASHTRA', 'DELHI', 'MAHARASHTRA'],
#     'Name': ['ECOVISION ENVIRONMENTAL RESOURCES LLP', 'Alliance Fibres Limited', 'THE SHAKTI PLASTIC INDUSTRIES', 'Timarpur-Okhla Waste Management Company Limited', 'MITTAL POLYGRAINS LLP'],
#     'Address': ['Survey No. 11, 12, 13, Opp. Torrent Power, Sub...', 'Block 203 & 208, MOTA BORASARA, KIM, TAL - MAN...', 'GUT NO 159 & 158, VILLAGE NANDGAON TURFE MANOR...', 'Old NDMC Compost Plant , Behind CRRI Mathura R...', 'Gut No. 41, Plot No. 27 & 28, Karodi, Aurangab...'],
#     'Email': ['info@eco-vision.co.in', 'info@alliancefibres.com', 'yogesh@shaktiplasticinds.com', 'sandip.dutt@jindalecopolis.com', 'accounts@mittalpolygrains.in'],
#     'Class': ['Plastic waste Recycling', 'Plastic waste Recycling', 'Plastic waste Recycling', 'Waste to energy Plants', 'Plastic waste Recycling'],
#     'Category': ['CAT I,CAT II', 'CAT I', 'CAT I,CAT II,CAT III', 'CAT I,CAT II,CAT III', 'CAT I,CAT II,CAT III'],
#     'Website': [''] * 5  # Add an empty column for website URLs
# })

# Set up Selenium webdriver (assuming you have Chrome installed)
driver = webdriver.Chrome()

# Iterate over the DataFrame rows
for index, row in df1[8:20].iterrows():
    name = row['Name']
    search_query = f"{name} website"
    
    # Search for the website using Google
    google_url = f"https://www.google.com/search?q={search_query}"
    driver.get(google_url)
    
    # Find the first search result link
#     search_results = driver.find_elements_by_css_selector('.yuRUbf > a')
#     if len(search_results) > 0:
#         website_url = search_results[0].get_attribute('href')
#         df.at[index, 'Website'] = website_url
        
#         # Open the website using Selenium
#         driver.get(website_url)
        # You can perform further actions on the website, such as scraping contact details
        # Use appropriate Selenium methods to interact with the website's elements
        
# Close the Selenium webdriver
#driver.quit()

# Display the updated DataFrame
print(df)
# Out:
# ---------------------------------------------------------------------------
# NoSuchWindowException                     Traceback (most recent call last)
# Cell In[12], line 24
#      22     # Search for the website using Google
#      23     google_url = f"https://www.google.com/search?q={search_query}"
# ---> 24     driver.get(google_url)
#      26     # Find the first search result link
#      27 #     search_results = driver.find_elements_by_css_selector('.yuRUbf > a')
#      28 #     if len(search_results) > 0:
#    (...)
#      39
#      40 # Display the updated DataFrame
#      41 print(df)
#
# File ~\anaconda3\envs\web_scapping\lib\site-packages\selenium\webdriver\remote\webdriver.py:449, in WebDriver.get(self, url)
#     447 def get(self, url: str) -> None:
#     448     """Loads a web page in the current browser session."""
# --> 449     self.execute(Command.GET, {"url": url})
#
# ...

# %%
from selenium import webdriver
from selenium import webdriver
from selenium.webdriver.firefox.options import Options
from selenium.webdriver.firefox.firefox_profile import FirefoxProfile

# Set up Firefox profile with custom user agent
profile = FirefoxProfile()
profile.set_preference("general.useragent.override", "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/93.0.4577.63 Safari/537.36")

# Set up Firefox options
options = Options()
options.profile = profile

# Set up Selenium webdriver (assuming you have Chrome installed)
driver = webdriver.Firefox(options=options)

# Iterate over the DataFrame rows
for index, row in df1[43:61].iterrows():
    name = row['Name']
    search_query = f"{name} website"
    
    # Search for the website using Google
    google_url = f"https://www.google.com/search?q={search_query}"
    driver.execute_script("window.open('');")  # Open a new window
    driver.switch_to.window(driver.window_handles[-1])  # Switch to the newly opened window
    driver.get(google_url)
    
    # Find the first search result link
#     search_results = driver.find_elements_by_css_selector('.yuRUbf > a')
#     if len(search_results) > 0:
#         website_url = search_results[0].get_attribute('href')
#         df.at[index, 'Website'] = website_url
        
        # Open the website in a new Chrome window
    #driver.execute_script(f"window.open('{website_url}');")
        
# Close the Selenium webdriver
#driver.quit()

# Display the updated DataFrame
print(df)
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_9628\670499512.py:7: DeprecationWarning: firefox_profile has been deprecated, please use an Options object
#   profile = FirefoxProfile()
# C:\Users\Admin\AppData\Local\Temp\ipykernel_9628\670499512.py:12: DeprecationWarning: Setting a profile has been deprecated. Please use the set_preference and install_addons methods
#   options.profile = profile
#          State                                             Name
# 0      GUJARAT            ECOVISION ENVIRONMENTAL RESOURCES LLP  \
# 1      GUJARAT                          Alliance Fibres Limited
# 2  MAHARASHTRA                    THE SHAKTI PLASTIC INDUSTRIES
# 3        DELHI  Timarpur-Okhla Waste Management Company Limited
# 4  MAHARASHTRA                            MITTAL POLYGRAINS LLP
#
#                                              Address
# 0  Survey No. 11, 12, 13, Opp. Torrent Power, Sub...  \
# 1  Block 203 & 208, MOTA BORASARA, KIM, TAL - MAN...
# ...

# %%
from selenium import webdriver
from selenium.webdriver.chrome.options import Options

# Set up Chrome options with custom user agent
options = Options()
options.add_argument("user-agent=Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/93.0.4577.63 Safari/537.36")

# Set up Selenium webdriver using Chrome with custom user agent
#driver = webdriver.Chrome(options=options)

driver = webdriver.Chrome((ChromeDriverManager().install()))
wait = WebDriverWait(driver,10)

# Iterate over the DataFrame rows
for index, row in df1[111:121].iterrows():
    name = row['Name']
    search_query = f"{name} website"
    
    # Search for the website using Google
    google_url = f"https://www.google.com/search?q={search_query}"
    time.sleep(5)
    driver.execute_script("window.open('');")  # Open a new window
    driver.switch_to.window(driver.window_handles[-1])  # Switch to the newly opened window
    driver.get(google_url)

# Close the Selenium webdriver
#driver.quit()
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_12048\3386839401.py:11: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver = webdriver.Chrome((ChromeDriverManager().install()))

# %%
# import time
# import requests
# from selenium import webdriver
# from selenium.webdriver.chrome.options import Options
# from webdriver_manager.chrome import ChromeDriverManager
# from selenium.webdriver.support.ui import WebDriverWait

# # Set up Chrome options with custom user agent
# options = Options()
# options.add_argument("user-agent=Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/93.0.4577.63 Safari/537.36")

# # Set up Selenium webdriver using Chrome with custom user agent
# driver = webdriver.Chrome(ChromeDriverManager().install(), options=options)
# wait = WebDriverWait(driver, 10)

# # Proxy configuration
# proxies = {
#     'http': 'http://your_proxy_address:your_proxy_port',
#     'https': 'https://your_proxy_address:your_proxy_port',
# }

# # Iterate over the DataFrame rows
# for index, row in df1[62:71].iterrows():
#     name = row['Name']
#     search_query = f"{name} website"

#     # Search for the website using Google
#     google_url = f"https://www.google.com/search?q={search_query}"

#     # Request the Google search page with a proxy
#     try:
#         response = requests.get(google_url, proxies=proxies)
#     except requests.exceptions.RequestException as e:
#         print(f"Error: {e}")
#         continue

#     # Parse the response with Selenium
#     driver.execute_script("window.open('');")  # Open a new window
#     driver.switch_to.window(driver.window_handles[-1])  # Switch to the newly opened window
#     driver.get("data:text/html;charset=utf-8," + response.text)

#     # Handle the bot detection message if prompted
#     if "Our systems have detected unusual traffic" in driver.page_source:
#         print("Bot detection triggered. Please manually solve the CAPTCHA.")

#     # Close the Selenium webdriver for each website to avoid excessive resource usage
#     driver.close()
#     driver.switch_to.window(driver.window_handles[-1])

# # Close the Selenium webdriver
# #driver.quit()
