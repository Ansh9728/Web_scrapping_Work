# %%
import pandas as pd

# %%
df = pd.read_excel('freightfor.xlsx',index_col=0)

# %%
df['Pin_code']=df['Address'].str.split(',').str[-1].str.strip()


#df.to_excel('Cha clean Pin location.xlsx')

# %%
df
# Out:
#                                                  Name  \
# 0           Ahmedabad Custom House Agents Association
# 1   Association of Custom House Agents Thiruvantha...
# 2          Aurangabad Custom House Agents Association
# 3       Bangalore Custom House Agents Association Ltd
# 4        Brihanmumbai Custom House Agents Association
# 5           Calcutta Customs House Agents Association
# 6             Chennai Custom House Agents Association
# 7              Cochin Custom House Agents Association
# 8      Coimbatore Custom House & Steamer Agents Asson
# 9          Customs House Agents Association Hyderabad
# 10          Delhi Customs Clearing Agents Association
# 11                Goa Custom House Agents Association
# 12             Indore Custom House Agents Association
# 13               Kakinada Customs Brokers Association
# 14             Kandla Custom House Agents Association
# 15           Ludhiana Custom House Agents Association
# ...

# %%
df['Pin_code'] = df['Pin_code'].str.split('-').str[-1]

# %%
df.to_excel('Straight forward clean Pin location.xlsx')
